# %%
#tensorflow stock predictor
import numpy as np
import pandas as pd
import yfinance as yf
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
import scipy

# Define the ticker symbol and download the historical data
ticker = "AAPL"
data = yf.download(ticker, start="2023-01-01", end="2023-03-31")



# Define the input and output variables
X = data[["Open", "High", "Low", "Close", "Volume"]]
y = data[["Adj Close"]]

# Scale the data using a MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
y_scaled = scaler.fit_transform(y)

# Split the data into training and testing sets
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size
X_train, X_test = X_scaled[0:train_size,:], X_scaled[train_size:len(X),:]
y_train, y_test = y_scaled[0:train_size,:], y_scaled[train_size:len(y),:]

# Define the neural network model
model = keras.Sequential()
model.add(keras.layers.Dense(64, input_dim=5, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(1, activation='linear'))

# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test))

# Evaluate the model
train_loss = model.evaluate(X_train, y_train, verbose=0)
test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Train Loss: {train_loss:.5f}')
print(f'Test Loss: {test_loss:.5f}')

# Plot the training and validation loss over time
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Make predictions using the trained model
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
y_test = scaler.inverse_transform(y_test)

# Plot the predicted and actual prices over time
plt.plot(predictions)
plt.plot(y_test)
plt.title('Predicted vs Actual Stock Price')
plt.ylabel('Price')
plt.xlabel('Time')
plt.legend(['Predicted', 'Actual'], loc='upper left')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/100
# 3/3 [==============================] - 2s 97ms/step - loss: 0.5828 - val_loss: 1.1396
# Epoch 2/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4463 - val_loss: 0.8467
# Epoch 3/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3224 - val_loss: 0.5951
# Epoch 4/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2101 - val_loss: 0.3928
# Epoch 5/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1339 - val_loss: 0.2333
# Epoch 6/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0706 - val_loss: 0.1233
# Epoch 7/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0359 - val_loss: 0.0545
# Epoch 8/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0149 - val_loss: 0.0169
# Epoch 9/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0053 - val_loss: 0.0024
# Epoch 10/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0040 - val_loss: 7.6443e-04
# Epoch 11/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0064 - val_loss: 0.0025
# Epoch 12/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0077 - val_loss: 0.0029
# Epoch 13/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0073 - val_loss: 0.0019
# Epoch 14/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 6.6958e-04
# Epoch 15/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0040 - val_loss: 4.1952e-04
# Epoch 16/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 17/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 18/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0054
# Epoch 19/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0023 - val_loss: 0.0061
# Epoch 20/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0023 - val_loss: 0.0058
# Epoch 21/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0047
# Epoch 22/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 23/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 24/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 25/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 26/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 27/100
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 28/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 29/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 30/100
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 31/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 32/100
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 33/100
# 3/3 [==============================] - 0s 13ms/step - loss: 9.6507e-04 - val_loss: 0.0017
# Epoch 34/100
# 3/3 [==============================] - 0s 16ms/step - loss: 9.1606e-04 - val_loss: 0.0017
# Epoch 35/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.8274e-04 - val_loss: 0.0016
# Epoch 36/100
# 3/3 [==============================] - 0s 14ms/step - loss: 8.3343e-04 - val_loss: 0.0016
# Epoch 37/100
-04
# Epoch 61/100
# 3/3 [==============================] - 0s 13ms/step - loss: 3.1625e-04 - val_loss: 8.9821e-04
# Epoch 62/100
# 3/3 [==============================] - 0s 15ms/step - loss: 3.0991e-04 - val_loss: 8.7356e-04
# Epoch 63/100
# 3/3 [==============================] - 0s 14ms/step - loss: 3.0407e-04 - val_loss: 8.7623e-04
# Epoch 64/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.9940e-04 - val_loss: 8.7269e-04
# Epoch 65/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.9483e-04 - val_loss: 8.7899e-04
# Epoch 66/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.9287e-04 - val_loss: 8.9644e-04
# Epoch 67/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.8674e-04 - val_loss: 8.5002e-04
# Epoch 68/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.8084e-04 - val_loss: 7.7388e-04
# Epoch 69/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.7839e-04 - val_loss: 7.3566e-04
# Epoch 70/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.7604e-04 - val_loss: 7.2118e-04
# Epoch 71/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.7107e-04 - val_loss: 7.8414e-04
# Epoch 72/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6891e-04 - val_loss: 8.5539e-04
# Epoch 73/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.6413e-04 - val_loss: 8.0374e-04
# Epoch 74/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6042e-04 - val_loss: 7.6776e-04
# Epoch 75/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.5327e-04 - val_loss: 6.9439e-04
# Epoch 76/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.5326e-04 - val_loss: 6.5991e-04
# Epoch 77/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.5092e-04 - val_loss: 6.4320e-04
# Epoch 78/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.4331e-04 - val_loss: 6.8451e-04
# Epoch 79/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.4052e-04 - val_loss: 6.9467e-04
# Epoch 80/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.3879e-04 - val_loss: 7.2287e-04
# Epoch 81/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.3431e-04 - val_loss: 6.8686e-04
# Epoch 82/100
# 3/3 [==============================] - 0s 13ms/step - loss: 2.2513e-04 - val_loss: 6.2908e-04
# Epoch 83/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.1815e-04 - val_loss: 5.6564e-04
# Epoch 84/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.1135e-04 - val_loss: 5.1657e-04
# Epoch 85/100
# 3/3 [==============================] - 0s 14ms/step - loss: 2.0626e-04 - val_loss: 4.9138e-04
# Epoch 86/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.0186e-04 - val_loss: 4.7263e-04
# Epoch 87/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.0017e-04 - val_loss: 4.6611e-04
# Epoch 88/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.9715e-04 - val_loss: 4.0679e-04
# Epoch 89/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1.9469e-04 - val_loss: 4.1143e-04
# Epoch 90/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.9119e-04 - val_loss: 4.0456e-04
# Epoch 91/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.8931e-04 - val_loss: 4.0604e-04
# Epoch 92/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.8851e-04 - val_loss: 3.8456e-04
# Epoch 93/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.8494e-04 - val_loss: 3.7443e-04
# Epoch 94/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.8204e-04 - val_loss: 4.0259e-04
# Epoch 95/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.8044e-04 - val_loss: 3.7440e-04
# Epoch 96/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.8209e-04 - val_loss: 3.8482e-04
# Epoch 97/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.7582e-04 - val_loss: 3.4297e-04
# Epoch 98/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1.7436e-04 - val_loss: 3.3226e-04
# Epoch 99/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.7299e-04 - val_loss: 3.5707e-04
# Epoch 100/100
# 3/3 [==============================] - 0s 13ms/step - loss: 1.7000e-04 - val_loss: 3.6481e-04
# Train Loss: 0.00017
# Test Loss: 0.00036
# 1/1 [==============================] - 0s 117ms/step
