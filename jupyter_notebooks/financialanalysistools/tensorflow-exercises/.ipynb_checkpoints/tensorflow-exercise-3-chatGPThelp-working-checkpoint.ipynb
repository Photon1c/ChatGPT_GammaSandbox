# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf
import tensorflow_quantum as tfq

# Define the stock to analyze
stock = yf.Ticker("AAPL")

# Download historical data
data = stock.history(period="max")

# Preprocess data
data["log_return"] = np.log(data["Close"] / data["Close"].shift(1))
data.dropna(inplace=True)

# Define the features and target
features = ["Open", "High", "Low", "Close", "Volume", "log_return"]
target = "log_return"

# Split data into training and testing sets
train_size = int(len(data) * 0.8)
train_data = data.iloc[:train_size]
test_data = data.iloc[train_size:]

# Define the neural network model
def create_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(units=64, activation="relu", input_shape=[len(features)]),
        tf.keras.layers.Dense(units=64, activation="relu"),
        tf.keras.layers.Dense(units=1)
    ])
    model.compile(optimizer=tf.optimizers.Adam(), loss="mean_squared_error")
    return model

# Train the model
model = create_model()
history = model.fit(train_data[features], train_data[target], epochs=100, validation_split=0.2)

# Evaluate the model
test_loss = model.evaluate(test_data[features], test_data[target])

# Plot the training and validation loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Train", "Validation"], loc="upper right")
plt.show()

# Print the test loss
print("Test loss:", test_loss)

# %%
pip install tensorflow_quantum

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf
import numpy as np

# Define the stock to analyze
stock = yf.Ticker("INTC")

# Download historical data
data = stock.history(period="max")

# Preprocess data
data["log_return"] = np.log(data["Close"] / data["Close"].shift(1))
data.dropna(inplace=True)

# Define the features and target
features = ["Open", "High", "Low", "Close", "Volume", "log_return"]
target = "log_return"

# Split data into training and testing sets
train_size = int(len(data) * 0.8)
train_data = data.iloc[:train_size]
test_data = data.iloc[train_size:]

# Define the neural network model
def create_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(units=64, activation="relu", input_shape=[len(features)]),
        tf.keras.layers.Dense(units=64, activation="relu"),
        tf.keras.layers.Dense(units=1)
    ])
    model.compile(optimizer=tf.optimizers.Adam(), loss="mean_squared_error")
    return model

# Train the model
model = create_model()
history = model.fit(train_data[features], train_data[target], epochs=100, validation_split=0.2)

# Evaluate the model
test_loss = model.evaluate(test_data[features], test_data[target])

# Plot the training and validation loss
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Train", "Validation"], loc="upper right")
plt.show()

# Make predictions on test data
test_predictions = model.predict(test_data[features]).flatten()

# Plot the predicted and actual log returns
plt.plot(test_data["log_return"], label="Actual")
plt.plot(test_predictions, label="Predicted")
plt.title("Actual vs. Predicted Log Returns")
plt.xlabel("Date")
plt.ylabel("Log Return")
plt.legend()
plt.show()

# Print the test loss
print("Test loss:", test_loss)
