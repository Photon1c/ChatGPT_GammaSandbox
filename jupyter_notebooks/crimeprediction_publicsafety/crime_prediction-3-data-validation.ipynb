# %%
import tensorflow as tf
import pandas as pd

# Load crime data
crime_data = pd.read_csv('crime_data.csv')

# Normalize the data
mean = crime_data.mean()
std = crime_data.std()
normalized_data = (crime_data - mean) / std

# Split the data into training and validation sets
train_data = normalized_data.sample(frac=0.8, random_state=0)
val_data = normalized_data.drop(train_data.index)

# Extract the input features and output targets
train_features = train_data[['population', 'median_income', 'median_age', 'housing_density']].values
train_targets = train_data['crime_rate'].values
val_features = val_data[['population', 'median_income', 'median_age', 'housing_density']].values
val_targets = val_data['crime_rate'].values

# Define the neural network model
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(4,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.RMSprop(),
              loss='mse',
              metrics=['mae'])

# Train the model
history = model.fit(train_features, train_targets, epochs=100, validation_data=(val_features, val_targets))

# Save the trained model to a file
model.save('crime_model.h5')
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 362ms/step - loss: 0.9766 - mae: 0.8969 - val_loss: 0.6769 - val_mae: 0.6269
# Epoch 2/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6462 - mae: 0.7352 - val_loss: 0.4936 - val_mae: 0.5669
# Epoch 3/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.4723 - mae: 0.6302 - val_loss: 0.3714 - val_mae: 0.5167
# Epoch 4/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.3577 - mae: 0.5486 - val_loss: 0.2875 - val_mae: 0.4748
# Epoch 5/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2760 - mae: 0.4811 - val_loss: 0.2250 - val_mae: 0.4381
# Epoch 6/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2144 - mae: 0.4218 - val_loss: 0.1761 - val_mae: 0.4015
# Epoch 7/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1653 - mae: 0.3670 - val_loss: 0.1339 - val_mae: 0.3606
# Epoch 8/100
# ...

# %%
pip uninstall tensorflow

# %%
pip install protobuf==3.20.*

# %%
pip install protobuf

# %%
pip install h5py==3.2.1
